# %% [markdown]
# ## Vinutha

# %% [markdown]
# ##  Task 1: Conceptual Answers (WRITE THIS IN NOTEBOOK)
# # 1. Difference between "Love" and "love" in NLP
# "Love" and "love" are treated as different tokens in case-sensitive systems
# This increases vocabulary size unnecessarily
# So we convert everything to lowercase → normalization
# # 2. What happens if stopwords are not removed?
# Model gets extra noise
# Slower processing
# Less meaningful features
# Example: “the”, “is”, “at” don’t add value in many cases
# # 3. When removing stopwords is harmful
#
# Sentiment Analysis
# “I am not happy” → removing “not” changes meaning
#
# Question Answering
# “What is the time?” → removing “what” loses intent
# # 4. Stemming vs Lemmatization
# Stemming	Lemmatization
# Cuts words	Converts to root meaning
# Faster	More accurate
# Example: "running" → "run" or "runn"	"running" → "run"

# %% [markdown]
# # Task 2: Preprocessing Function

# %%
import re

def preprocess_text(text):
    if not isinstance(text, str) or text.strip() == "":
        return [], ""

    # Remove URLs & emails
    text = re.sub(r"http\S+|www\S+|@\S+", "", text)

    # Remove numbers
    text = re.sub(r"\d+", "", text)

    # Lowercase
    text = text.lower()

    # Handle repeated characters (soooo → soo)
    text = re.sub(r'(.)\1{2,}', r'\1\1', text)

    # Remove special characters & emojis
    text = re.sub(r'[^\w\s]', '', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    tokens = text.split()

    # Remove short tokens (≤2 except 'no', 'not')
    tokens = [word for word in tokens if len(word) > 2 or word in ['no', 'not']]

    clean_sentence = " ".join(tokens)

    return tokens, clean_sentence

# %% [markdown]
# # Task 3: Stress Testing

# %%
test_sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

results = []

for text in test_sentences:
    tokens, clean = preprocess_text(text)
    
    print("\nOriginal:", text)
    print("Tokens:", tokens)
    print("Clean Sentence:", clean)
    
    results.append(tokens)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Clean Sentence: get free access now
#
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'looved', 'this', 'product']
# Clean Sentence: absolutely looved this product
#
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Clean Sentence: worst service ever
#
# Original: Call me at 9876543210
# Tokens: ['call']
# Clean Sentence: call
#
# Original: This is THE best course!!!
# Tokens: ['this', 'the', 'best', 'course']
# Clean Sentence: this the best course
#
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Clean Sentence: visit now
#
# Original: Nooooo this is baaad!!!
# Tokens: ['noo', 'this', 'baad']
# Clean Sentence: noo this baad
#
# Original: OK OK OK I got it
# Tokens: ['got']
# Clean Sentence: got
#
# Original: Win $$$ now!!! Limited offer!!!
# Tokens: ['win', 'now', 'limited', 'offer']
# ...

# %% [markdown]
# # Task 4: Token Analytics

# %%
import numpy as np

for text in test_sentences:
    tokens, _ = preprocess_text(text)

    total_tokens = len(tokens)
    unique_tokens = len(set(tokens))
    avg_length = np.mean([len(word) for word in tokens]) if tokens else 0

    print("\nSentence:", text)
    print("Total Tokens:", total_tokens)
    print("Unique Tokens:", unique_tokens)
    print("Avg Token Length:", avg_length)
# Out:
# Sentence: Get 100% FREE access now!!!
# Total Tokens: 4
# Unique Tokens: 4
# Avg Token Length: 4.0
#
# Sentence: I absolutely looooved this product 😍😍
# Total Tokens: 4
# Unique Tokens: 4
# Avg Token Length: 6.75
#
# Sentence: Worst service ever... 0/10
# Total Tokens: 3
# Unique Tokens: 3
# Avg Token Length: 5.333333333333333
#
# Sentence: Call me at 9876543210
# Total Tokens: 1
# Unique Tokens: 1
# Avg Token Length: 4.0
#
# Sentence: This is THE best course!!!
# Total Tokens: 4
# Unique Tokens: 4
# Avg Token Length: 4.25
#
# Sentence: Visit https://openai.com now!
# Total Tokens: 2
# Unique Tokens: 2
# Avg Token Length: 4.0
#
# Sentence: Nooooo this is baaad!!!
# Total Tokens: 3
# Unique Tokens: 3
# Avg Token Length: 3.6666666666666665
#
# Sentence: OK OK OK I got it
# Total Tokens: 1
# Unique Tokens: 1
# Avg Token Length: 3.0
#
# Sentence: Win $$$ now!!! Limited offer!!!
# Total Tokens: 4
# Unique Tokens: 4
# Avg Token Length: 4.5
#
# Sentence: I am not happy with this
# ...

# %% [markdown]
# # Task 5: Frequency Analysis

# %%
from collections import Counter

all_tokens = []

for text in test_sentences:
    tokens, _ = preprocess_text(text)
    all_tokens.extend(tokens)

counter = Counter(all_tokens)

print("Top 10 Frequent:", counter.most_common(10))
print("Least 5 Frequent:", counter.most_common()[-5:])
# Out:
# Top 10 Frequent: [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('looved', 1), ('product', 1), ('worst', 1), ('service', 1)]
# Least 5 Frequent: [('limited', 1), ('offer', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %% [markdown]
# # Task 6: Full Pipeline

# %% [markdown]
# def full_pipeline(text_list):
#     all_tokens = []
#     clean_sentences = []
#
#     for text in text_list:
#         tokens, clean = preprocess_text(text)
#         all_tokens.extend(tokens)
#         clean_sentences.append(clean)
#
#     return {
#         "tokens": all_tokens,
#         "clean_sentences": clean_sentences
#     }
